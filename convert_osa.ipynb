# %%
import pandas as pd

# %%
df = pd.read_parquet('input/bases_osa.parquet')
df
# Out:
#                DATA            CNPJ CATEGORIA         FAMILIA  SELLOUT_TON  \
# 0        2023-01-01  10194833000194  BISCUITS         BELVITA     0.267600
# 1        2023-01-01  10194833000194  BISCUITS     CLUB SOCIAL     3.599200
# 2        2023-01-01  10194833000194  BISCUITS            OREO     1.557800
# 3        2023-01-01  10194833000194  BISCUITS  OTHER BISCUITS     0.098600
# 4        2023-01-01  10194833000194  BISCUITS        TRAKINAS     3.798867
# ...             ...             ...       ...             ...          ...
# 22553568 2024-12-01  97422620007910        PB          CLIGHT     0.002984
# 22553569 2024-12-01  97422620007910        PB           FRESH     0.001425
# 22553570 2024-12-01  97422620007910        PB            TANG     0.011448
# 22553571 2024-12-01  97550909000155        PB          CLIGHT     0.030000
# 22553572 2024-12-01  97550909000155        PB            TANG     0.090000
#
#           SELLOUT_REAIS
# 0                  0.00
# ...

# %%
df = df[df['DATA'] >= '2025-01-01']
df.to_parquet('osa_p01_p08_25.parquet', index=False)

# %%
df
# Out:
#                DATA            CNPJ CATEGORIA         FAMILIA  SELLOUT_TON  \
# 476058   2025-01-01  10194833000194  BISCUITS  76222105283000     0.025350
# 476059   2025-01-01  10194833000194  BISCUITS  76222105283300     0.016725
# 476060   2025-01-01  10194833000194  BISCUITS  76222105286900     0.058725
# 476061   2025-01-01  10194833000194  BISCUITS  76222105287200     0.024750
# 476062   2025-01-01  10194833000194  BISCUITS  76222105322500     0.152562
# ...             ...             ...       ...             ...          ...
# 16671352 2025-08-01  97422620007163        PB  76222106963372     0.000480
# 16671353 2025-08-01  97422620007163        PB  76222106963773     0.001680
# 16671354 2025-08-01  97422620007163        PB  76222106964473     0.003168
# 16671355 2025-08-01  97422620007163        PB  76222106965973     0.000976
# 16671356 2025-08-01  97422620007163        PB  76222106966373     0.000600
#
#           SELLOUT_REAIS
# 476058             0.00
# ...
